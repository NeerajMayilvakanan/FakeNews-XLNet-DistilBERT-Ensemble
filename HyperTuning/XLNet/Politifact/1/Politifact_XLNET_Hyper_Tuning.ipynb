# %%
pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.34.0-py3-none-any.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 26.2 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.4)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers)
#   Downloading huggingface_hub-0.18.0-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 36.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Collecting tokenizers<0.15,>=0.14 (from transformers)
#   Downloading tokenizers-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 59.6 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 58.4 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers)
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 34.1 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Installing collected packages: safetensors, huggingface-hub, tokenizers, transformers
# Successfully installed huggingface-hub-0.17.3 safetensors-0.4.0 tokenizers-0.14.1 transformers-4.34.0

# %%
pip install sentencepiece
# Out:
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 10.5 MB/s eta 0:00:00
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.99

# %%
pip install accelerate -U
# Out:
# Collecting accelerate
#   Downloading accelerate-0.23.0-py3-none-any.whl (258 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.1/258.1 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.0.1+cu118)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.17.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.12.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.10.0->accelerate) (3.27.6)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.10.0->accelerate) (17.0.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Installing collected packages: accelerate
# Successfully installed accelerate-0.23.0

# %%
pip install transformers optuna
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.34.0)
# Collecting optuna
#   Downloading optuna-3.4.0-py3-none-any.whl (409 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.6/409.6 kB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.17.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.14.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.12.0-py3-none-any.whl (226 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.0/226.0 kB 8.0 MB/s eta 0:00:00
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.21)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.5.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.3)
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.2.4 alembic-1.12.0 colorlog-6.7.0 optuna-3.4.0

# %%
import torch
from transformers import XLNetForSequenceClassification, XLNetTokenizer
from transformers import Trainer, TrainingArguments
from transformers import DataCollatorForLanguageModeling
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import numpy as np
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import optuna

# %%
model_name = "xlnet-base-cased"
tokenizer = XLNetTokenizer.from_pretrained(model_name)
# Out:
# Downloading (…)ve/main/spiece.model:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.38M [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/760 [00:00<?, ?B/s]

# %%
# Load dataset
import pandas as pd
df = pd.read_csv("/content/gdrive/MyDrive/fake_news/FakeNewsNet_DS/politifact_cleaned.csv")
df['SECTION_CLEANED'] = df['SECTION_CLEANED'].astype(str)

# Randomly select  % of the data
df_data = df.sample(frac=1.0, random_state=42)


# Split the dataset into training, validation, and test sets
# First, split into training and temp sets (80% training, 20% temp)
train_df, temp_df = train_test_split(df_data, test_size=0.20, random_state=42)

# Then, split the temp set into validation and test sets (50% validation, 50% test)
validation_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=42)

# Optionally,reset the index of the DataFrames
train_df = train_df.reset_index(drop=True)
validation_df = validation_df.reset_index(drop=True)
test_df = test_df.reset_index(drop=True)

# %%
df.groupby("label").describe()
# Out:
#       Unnamed: 0                                                           \
#            count   mean         std    min     25%    50%     75%     max
# label
# 0          432.0  839.5  124.851912  624.0  731.75  839.5  947.25  1055.0
# 1          624.0  311.5  180.277564    0.0  155.75  311.5  467.25   623.0
#
#       word count
#            count       mean       std  min  25%   50%   75%   max
# label
# 0          432.0  11.701389  5.222315  1.0  9.0  11.0  14.0  38.0
# 1          624.0   7.931090  4.665029  1.0  5.0   7.0  10.0  53.0

# %%
train_df.groupby("label").describe()
# Out:
#       Unnamed: 0                                                             \
#            count     mean         std    min     25%    50%     75%     max
# label
# 0          344.0  842.250  127.068042  624.0  728.75  848.0  954.25  1055.0
# 1          500.0  316.502  177.314068    0.0  167.75  321.5  466.50   623.0
#
#       word count
#            count      mean       std  min  25%   50%   75%   max
# label
# 0          344.0  11.56686  5.280599  1.0  9.0  11.0  14.0  38.0
# 1          500.0   7.96000  4.706453  1.0  4.0   7.0  10.0  53.0

# %%
validation_df.groupby("label").describe()
# Out:
#       Unnamed: 0                                                        \
#            count        mean         std    min     25%    50%     75%
# label
# 0           44.0  805.795455  104.407426  629.0  732.75  795.5  857.50
# 1           62.0  307.677419  196.936852   39.0  113.25  297.5  499.25
#
#               word count
#           max      count       mean       std  min  25%   50%    75%   max
# label
# 0      1046.0       44.0  11.795455  5.428519  2.0  9.0  12.0  13.25  37.0
# 1       622.0       62.0   8.161290  5.353698  1.0  5.0   7.5   9.00  31.0

# %%
test_df.groupby("label").describe()
# Out:
#       Unnamed: 0                                                        \
#            count        mean         std    min     25%    50%     75%
# label
# 0           44.0  851.704545  123.172516  625.0  758.75  862.0  951.25
# 1           62.0  274.983871  185.405227    6.0  126.50  251.5  421.75
#
#               word count
#           max      count       mean       std  min   25%   50%    75%   max
# label
# 0      1050.0       44.0  12.659091  4.513253  5.0  10.0  12.0  14.25  30.0
# 1       618.0       62.0   7.467742  3.481651  1.0   5.0   7.0  10.00  16.0

# %%
df.head()
# Out:
#    Unnamed: 0               id  \
# 0           0  politifact14984
# 1           1  politifact12944
# 2           2    politifact333
# 3           3   politifact4358
# 4           4    politifact779
#
#                                                title  label  word count  \
# 0        National Federation of Independent Business      1           5
# 1                        comments in Fayetteville NC      1           4
# 2  Romney makes pitch, hoping to close deal : Ele...      1          14
# 3  Democratic Leaders Say House Democrats Are Uni...      1          11
# 4    Budget of the United States Government, FY 2008      1           8
#
#                                      SECTION_CLEANED
# 0           National Federation Independent Business
# 1                            comment Fayetteville NC
# 2  Romney make pitch hop close deal Elections The...
# 3  Democratic Leaders Say House Democrats Are Uni...
# 4            Budget United States Government FY 2008

# %%
train_texts = list(train_df['SECTION_CLEANED'])
len(train_texts)
# Out:
# 844

# %%
train_labels = list(train_df['label'])
len(train_labels)
# Out:
# 844

# %%
train_df.head(10)
# Out:
#    Unnamed: 0               id  \
# 0         262   politifact1825
# 1         816  politifact14085
# 2         538   politifact6998
# 3         495   politifact9442
# 4         266   politifact8172
# 5         620    politifact329
# 6         688  politifact13982
# 7         148   politifact6603
# 8         702  politifact13038
# 9         887  politifact15416
#
#                                                title  label  word count  \
# 0           'This Week' Transcript: Kaine and Steele      1           6
# 1  BREAKING: Bill O’Reilly In Critical Condition ...      0          12
# 2  The full transcript of the third presidential ...      1           8
# 3  a director of research for the foreign policy ...      1          13
# 4  Remarks by the President on Responsible Homeow...      1           7
# 5                           Change We Can Believe In      1           5
# 6  Kasich: “If A Woman Is Not Intelligent Enough ...      0          22
# 7  Ad says Obama apologized, showed weakness on Iran      1           8
# 8        The numbers don't lie... - Occupy Democrats      0           7
# 9     Attorney General Sessions Statement on Recusal      0           6
#
#                                      SECTION_CLEANED
# 0                  This Week Transcript Kaine Steele
# 1  BREAKING Bill OReilly In Critical Condition Af...
# 2      The full transcript third presidential debate
# 3  director research foreign policy program Brook...
# 4        Remarks President Responsible Homeownership
# 5                           Change We Can Believe In
# 6  Kasich “If A Woman Is Not Intelligent Enough T...
# 7          Ad say Obama apologize show weakness Iran
# 8               The number dont lie Occupy Democrats
# 9        Attorney General Sessions Statement Recusal

# %%
from torch.utils.data import Dataset

class CustomDataset(Dataset):
    def __init__(self, tokenized_data, labels):
        self.input_ids = tokenized_data["input_ids"]
        self.attention_mask = tokenized_data["attention_mask"]
        self.labels = torch.tensor(labels)

    def __len__(self):
        return len(self.input_ids)

    def __getitem__(self, idx):
        return {
            "input_ids": self.input_ids[idx],
            "attention_mask": self.attention_mask[idx],
            "labels": self.labels[idx],
        }

# %%
# Tokenize and format data
train_encodings = tokenizer(train_texts, padding=True, truncation=True, return_tensors="pt", max_length=128)
#tokenized_data = tokenizer(train_texts, padding=True, truncation=False, return_tensors="pt")
train_labels = torch.tensor(train_labels)
train_dataset = CustomDataset(train_encodings, train_labels)
# Out:
# <ipython-input-19-91207c483471>:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.labels = torch.tensor(labels)

# %%
# Create a PyTorch dataset for validation
from torch.utils.data import Dataset

class CustomValidationDataset(Dataset):
    def __init__(self, tokenized_data, labels):
        self.input_ids = tokenized_data["input_ids"]
        self.attention_mask = tokenized_data["attention_mask"]
        self.labels = torch.tensor(labels)

    def __len__(self):
        return len(self.input_ids)

    def __getitem__(self, idx):
        return {
            "input_ids": self.input_ids[idx],
            "attention_mask": self.attention_mask[idx],
            "labels": self.labels[idx],
        }

# %%
val_texts = list(validation_df['SECTION_CLEANED'])
len(val_texts)
# Out:
# 106

# %%
val_labels = list(validation_df['label'])
len(val_labels)
# Out:
# 106

# %%
# Tokenize and format data
val_encodings = tokenizer(val_texts, padding=True, truncation=True, return_tensors="pt", max_length=128)

val_labels = torch.tensor(val_labels)
validation_dataset = CustomValidationDataset(val_encodings, val_labels)
# Out:
# <ipython-input-22-409cfb690dd2>:8: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.labels = torch.tensor(labels)

# %%
# Define the training arguments
training_args = TrainingArguments(
    output_dir="./XLNET/TrainingArgs/",
    evaluation_strategy="steps",  # Evaluate every `eval_steps`
    eval_steps=75,  # Adjust as needed
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    warmup_steps=500,
    weight_decay=0.01,
    logging_dir="./XLNET/Logs/",
    logging_steps=75,
    learning_rate=5e-5,
    num_train_epochs=2
)

# %%
# Define a function for training and evaluation
def train_and_evaluate(trial):
    # Define the hyperparameters to optimize

    num_train_epochs = trial.suggest_int("num_train_epochs", 1, 3)
    per_device_train_batch_size = trial.suggest_categorical("per_device_train_batch_size", [4, 8, 16])
    learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 5e-5)
    weight_decay = trial.suggest_loguniform("weight_decay", 1e-3, 1e-1)
    warmup_steps = trial.suggest_int("warmup_steps", 100, 800)

    # Update the training arguments
    training_args.num_train_epochs = num_train_epochs
    training_args.per_device_train_batch_size = per_device_train_batch_size
    training_args.weight_decay = weight_decay
    training_args.warmup_steps = warmup_steps
    training_args.learning_rate = learning_rate


    model_name = "xlnet-base-cased"
    model = XLNetForSequenceClassification.from_pretrained(model_name)

    # Create a Trainer instance
    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=train_dataset,
        eval_dataset=validation_dataset,

    )

    # Train the model
    trainer.train()

    # Evaluate the model
    results = trainer.evaluate(validation_dataset)
    print("Evaluation Results:", results)

    model = 45
    return results["eval_loss"]

# %%
# Create an Optuna study
study = optuna.create_study(direction="minimize")
# Out:
# [I 2023-10-18 10:01:13,805] A new study created in memory with name: no-name-11b4f7a9-f5ca-48ce-8453-c48157464e41

# %%
# Optimize hyperparameters
study.optimize(train_and_evaluate, n_trials=10)
# Out:
# <ipython-input-36-62538d52347d>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 5e-5)
# <ipython-input-36-62538d52347d>:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-3, 1e-1)
# Some weights of XLNetForSequenceClassification were not initialized from the model checkpoint at xlnet-base-cased and are newly initialized: ['logits_proj.weight', 'sequence_summary.summary.weight', 'logits_proj.bias', 'sequence_summary.summary.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='318' max='318' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [318/318 00:46, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>75</td>
#       <td>0.726700</td>
#       <td>0.550796</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.521000</td>
#       <td>0.450003</td>
#     </tr>
#     <tr>
#       <td>225</td>
#       <td>0.533700</td>
#       <td>0.338703</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.467200</td>
#       <td>0.378694</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='14' max='14' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [14/14 00:00]
#     </div>
# [I 2023-10-18 10:02:03,914] Trial 0 finished with value: 0.43337854743003845 and parameters: {'num_train_epochs': 3, 'per_device_train_batch_size': 8, 'learning_rate': 3.602654015986219e-05, 'weight_decay': 0.06706898340146025, 'warmup_steps': 505}. Best is trial 0 with value: 0.43337854743003845.
# Evaluation Results: {'eval_loss': 0.43337854743003845, 'eval_runtime': 0.3363, 'eval_samples_per_second': 315.188, 'eval_steps_per_second': 41.629, 'epoch': 3.0}
# Some weights of XLNetForSequenceClassification were not initialized from the model checkpoint at xlnet-base-cased and are newly initialized: ['logits_proj.weight', 'sequence_summary.summary.weight', 'logits_proj.bias', 'sequence_summary.summary.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='318' max='318' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [318/318 00:46, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>75</td>
#       <td>0.723000</td>
#       <td>0.607894</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.597600</td>
#       <td>0.530598</td>
#     </tr>
#     <tr>
#       <td>225</td>
#       <td>0.577900</td>
#       <td>0.413066</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.483400</td>
#       <td>0.368947</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='14' max='14' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [14/14 00:00]
#     </div>
# [I 2023-10-18 10:02:51,934] Trial 1 finished with value: 0.35890182852745056 and parameters: {'num_train_epochs': 3, 'per_device_train_batch_size': 8, 'learning_rate': 1.5604874773406454e-05, 'weight_decay': 0.009433591406637187, 'warmup_steps': 658}. Best is trial 1 with value: 0.35890182852745056.
# Evaluation Results: {'eval_loss': 0.35890182852745056, 'eval_runtime': 0.3385, 'eval_samples_per_second': 313.15, 'eval_steps_per_second': 41.359, 'epoch': 3.0}
# Some weights of XLNetForSequenceClassification were not initialized from the model checkpoint at xlnet-base-cased and are newly initialized: ['logits_proj.weight', 'sequence_summary.summary.weight', 'logits_proj.bias', 'sequence_summary.summary.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='212' max='212' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [212/212 00:30, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>75</td>
#       <td>0.694200</td>
#       <td>0.565865</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.520100</td>
#       <td>0.397945</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='14' max='14' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [14/14 00:00]
#     </div>
# [I 2023-10-18 10:03:23,968] Trial 2 finished with value: 0.5697802901268005 and parameters: {'num_train_epochs': 2, 'per_device_train_batch_size': 8, 'learning_rate': 2.8178552706970022e-05, 'weight_decay': 0.0023279892724934388, 'warmup_steps': 433}. Best is trial 1 with value: 0.35890182852745056.
# Evaluation Results: {'eval_loss': 0.5697802901268005, 'eval_runtime': 0.3371, 'eval_samples_per_second': 314.436, 'eval_steps_per_second': 41.529, 'epoch': 2.0}
# Some weights of XLNetForSequenceClassification were not initialized from the model checkpoint at xlnet-base-cased and are newly initialized: ['logits_proj.weight', 'sequence_summary.summary.weight', 'logits_proj.bias', 'sequence_summary.summary.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='212' max='212' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [212/212 00:30, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>75</td>
#       <td>0.638000</td>
#       <td>0.469851</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.516200</td>
#       <td>0.373084</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='14' max='14' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [14/14 00:00]
#     </div>
# [I 2023-10-18 10:03:56,033] Trial 3 finished with value: 0.3426276445388794 and parameters: {'num_train_epochs': 2, 'per_device_train_batch_size': 8, 'learning_rate': 1.806188187351229e-05, 'weight_decay': 0.00414066063150564, 'warmup_steps': 115}. Best is trial 3 with value: 0.3426276445388794.
# Evaluation Results: {'eval_loss': 0.3426276445388794, 'eval_runtime': 0.3362, 'eval_samples_per_second': 315.274, 'eval_steps_per_second': 41.64, 'epoch': 2.0}
# Some weights of XLNetForSequenceClassification were not initialized from the model checkpoint at xlnet-base-cased and are newly initialized: ['logits_proj.weight', 'sequence_summary.summary.weight', 'logits_proj.bias', 'sequence_summary.summary.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='422' max='422' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [422/422 00:46, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>75</td>
#       <td>0.701500</td>
#       <td>0.538629</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.573900</td>
#       <td>0.480980</td>
#     </tr>
#     <tr>
#       <td>225</td>
#       <td>0.589200</td>
#       <td>0.721227</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.713900</td>
#       <td>0.878779</td>
#     </tr>
#     <tr>
#       <td>375</td>
#       <td>0.763100</td>
#       <td>0.657498</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='14' max='14' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [14/14 00:00]
#     </div>
# [I 2023-10-18 10:04:44,973] Trial 4 finished with value: 0.5085060000419617 and parameters: {'num_train_epochs': 2, 'per_device_train_batch_size': 4, 'learning_rate': 4.9897704396437724e-05, 'weight_decay': 0.0021769253602111926, 'warmup_steps': 249}. Best is trial 3 with value: 0.3426276445388794.
# Evaluation Results: {'eval_loss': 0.5085060000419617, 'eval_runtime': 0.3632, 'eval_samples_per_second': 291.873, 'eval_steps_per_second': 38.549, 'epoch': 2.0}
# Some weights of XLNetForSequenceClassification were not initialized from the model checkpoint at xlnet-base-cased and are newly initialized: ['logits_proj.weight', 'sequence_summary.summary.weight', 'logits_proj.bias', 'sequence_summary.summary.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='422' max='422' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [422/422 00:47, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>75</td>
#       <td>0.706900</td>
#       <td>0.648512</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.618400</td>
#       <td>0.449250</td>
#     </tr>
#     <tr>
#       <td>225</td>
#       <td>0.482900</td>
#       <td>0.458875</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.543000</td>
#       <td>0.533242</td>
#     </tr>
#     <tr>
#       <td>375</td>
#       <td>0.521700</td>
#       <td>0.412006</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='14' max='14' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [14/14 00:00]
#     </div>
# [I 2023-10-18 10:05:35,264] Trial 5 finished with value: 0.6956506371498108 and parameters: {'num_train_epochs': 2, 'per_device_train_batch_size': 4, 'learning_rate': 1.8300973924433692e-05, 'weight_decay': 0.005992331803920157, 'warmup_steps': 440}. Best is trial 3 with value: 0.3426276445388794.
# Evaluation Results: {'eval_loss': 0.6956506371498108, 'eval_runtime': 0.3728, 'eval_samples_per_second': 284.344, 'eval_steps_per_second': 37.555, 'epoch': 2.0}
# Some weights of XLNetForSequenceClassification were not initialized from the model checkpoint at xlnet-base-cased and are newly initialized: ['logits_proj.weight', 'sequence_summary.summary.weight', 'logits_proj.bias', 'sequence_summary.summary.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='211' max='211' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [211/211 00:22, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>75</td>
#       <td>0.693100</td>
#       <td>0.660501</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.597000</td>
#       <td>0.480627</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='14' max='14' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [14/14 00:00]
#     </div>
# [I 2023-10-18 10:06:00,300] Trial 6 finished with value: 0.4409668743610382 and parameters: {'num_train_epochs': 1, 'per_device_train_batch_size': 4, 'learning_rate': 4.123105218123473e-05, 'weight_decay': 0.09821656204406749, 'warmup_steps': 495}. Best is trial 3 with value: 0.3426276445388794.
# Evaluation Results: {'eval_loss': 0.4409668743610382, 'eval_runtime': 0.3503, 'eval_samples_per_second': 302.601, 'eval_steps_per_second': 39.966, 'epoch': 1.0}
# Some weights of XLNetForSequenceClassification were not initialized from the model checkpoint at xlnet-base-cased and are newly initialized: ['logits_proj.weight', 'sequence_summary.summary.weight', 'logits_proj.bias', 'sequence_summary.summary.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='106' max='106' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [106/106 00:15, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>75</td>
#       <td>0.713600</td>
#       <td>0.574622</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='14' max='14' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [14/14 00:00]
#     </div>
# [I 2023-10-18 10:06:18,217] Trial 7 finished with value: 0.5398428440093994 and parameters: {'num_train_epochs': 1, 'per_device_train_batch_size': 8, 'learning_rate': 2.756880134018089e-05, 'weight_decay': 0.014446019984275756, 'warmup_steps': 504}. Best is trial 3 with value: 0.3426276445388794.
# Evaluation Results: {'eval_loss': 0.5398428440093994, 'eval_runtime': 0.3326, 'eval_samples_per_second': 318.746, 'eval_steps_per_second': 42.098, 'epoch': 1.0}
# Some weights of XLNetForSequenceClassification were not initialized from the model checkpoint at xlnet-base-cased and are newly initialized: ['logits_proj.weight', 'sequence_summary.summary.weight', 'logits_proj.bias', 'sequence_summary.summary.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='211' max='211' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [211/211 00:23, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>75</td>
#       <td>0.729500</td>
#       <td>0.593716</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.548300</td>
#       <td>0.410027</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='14' max='14' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [14/14 00:00]
#     </div>
# [I 2023-10-18 10:06:43,444] Trial 8 finished with value: 0.4572209119796753 and parameters: {'num_train_epochs': 1, 'per_device_train_batch_size': 4, 'learning_rate': 4.244118358332528e-05, 'weight_decay': 0.013559843189046185, 'warmup_steps': 607}. Best is trial 3 with value: 0.3426276445388794.
# Evaluation Results: {'eval_loss': 0.4572209119796753, 'eval_runtime': 0.3425, 'eval_samples_per_second': 309.449, 'eval_steps_per_second': 40.871, 'epoch': 1.0}
# Some weights of XLNetForSequenceClassification were not initialized from the model checkpoint at xlnet-base-cased and are newly initialized: ['logits_proj.weight', 'sequence_summary.summary.weight', 'logits_proj.bias', 'sequence_summary.summary.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='422' max='422' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [422/422 00:46, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>75</td>
#       <td>0.725200</td>
#       <td>0.529953</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.542500</td>
#       <td>0.511722</td>
#     </tr>
#     <tr>
#       <td>225</td>
#       <td>0.566000</td>
#       <td>0.475103</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.557400</td>
#       <td>0.691603</td>
#     </tr>
#     <tr>
#       <td>375</td>
#       <td>0.552400</td>
#       <td>0.340371</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='14' max='14' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [14/14 00:00]
#     </div>
# [I 2023-10-18 10:07:31,696] Trial 9 finished with value: 0.37385496497154236 and parameters: {'num_train_epochs': 2, 'per_device_train_batch_size': 4, 'learning_rate': 2.49820442620097e-05, 'weight_decay': 0.024046398727177384, 'warmup_steps': 210}. Best is trial 3 with value: 0.3426276445388794.
# Evaluation Results: {'eval_loss': 0.37385496497154236, 'eval_runtime': 0.3385, 'eval_samples_per_second': 313.185, 'eval_steps_per_second': 41.364, 'epoch': 2.0}

# %%
# Get the best hyperparameters
best_params = study.best_params
best_num_train_epochs = best_params["num_train_epochs"]
best_batch_size = best_params["per_device_train_batch_size"]
best_learning_rate = best_params["learning_rate"]
best_weight_decay = best_params["weight_decay"]
best_warmup_steps = best_params["warmup_steps"]
# Print the best hyperparameters
print(f"Best Number of Epochs: {best_num_train_epochs}")
print(f"Best Batch Size: {best_batch_size}")
print(f"Best Learning Rate: {best_learning_rate}")
print(f"Best Weight Decay: {best_weight_decay}")
print(f"Best Warmup Steps: {best_warmup_steps}")
# Out:
# Best Number of Epochs: 2
# Best Batch Size: 8
# Best Learning Rate: 1.806188187351229e-05
# Best Weight Decay: 0.00414066063150564
# Best Warmup Steps: 115
